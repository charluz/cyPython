# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

img = mpimg.imread('church.jpg')
plt.imshow(img)
plt.show()

img.shape[0]
#plt.imshow(img, interpolation='none')
# Out:
# 168

# %%
x, y = np.mgrid[0:img.shape[0], 0:img.shape[1]]
ax = plt.gca(projection='3d')
#ax.plot_surface(x, y, np.sin(0.02*x)*np.sin(0.02*y), rstride=2, cstride=2,
#                facecolors=img)
ax.plot_surface(x, y, img[y,x,1], rstride=2, cstride=2,facecolors=img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/cy_conda/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-16f1224c3959> in <module>()
#       4 #                facecolors=img)
#       5 ax.plot_surface(x, y, img[x,y,1], rstride=2, cstride=2,
# ----> 6                 facecolors=img)
#       7 plt.show()
#
# ~/anaconda3/envs/cy_conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1738         if fcolors is not None:
#    1739             if shade:
# -> 1740                 colset = self._shade_colors(colset, normals)
#    1741             polyc.set_facecolors(colset)
#    1742             polyc.set_edgecolors(colset)
#
# ~/anaconda3/envs/cy_conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in _shade_colors(self, color, normals)
#    1788             norm = Normalize(min(shade[mask]), max(shade[mask]))
#    1789             shade[~mask] = min(shade[mask])
# -> 1790             color = mcolors.to_rgba_array(color)
#    1791             # shape of color should be (M, 4) (where M is number of faces)
#    1792             # shape of shade should be (M,)
#
# ~/anaconda3/envs/cy_conda/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     265     result = np.empty((len(c), 4), float)
#     266     for i, cc in enumerate(c):
# --> 267         result[i] = to_rgba(cc, alpha)
#     268     return result
#     269
#
# ~/anaconda3/envs/cy_conda/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#     170             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda3/envs/cy_conda/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     227         c = c[:3] + (alpha,)
#     228     if any(elem < 0 or elem > 1 for elem in c):
# --> 229         raise ValueError("RGBA values should be within 0-1 range")
#     230     return c
#     231
#
# ValueError: RGBA values should be within 0-1 range
